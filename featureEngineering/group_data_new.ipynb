# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
# Reading data
listings = pd.read_csv('..\dataset_filter\listings_3.csv')
listings.shape
listings
# Out:
#             id                            listing_url     scrape_id  \
# 0       241032    https://www.airbnb.com/rooms/241032  2.016010e+13
# 1       953595    https://www.airbnb.com/rooms/953595  2.016010e+13
# 2      3308979   https://www.airbnb.com/rooms/3308979  2.016010e+13
# 3      7421966   https://www.airbnb.com/rooms/7421966  2.016010e+13
# 4       278830    https://www.airbnb.com/rooms/278830  2.016010e+13
# ...        ...                                    ...           ...
# 3813   8101950   https://www.airbnb.com/rooms/8101950  2.016010e+13
# 3814   8902327   https://www.airbnb.com/rooms/8902327  2.016010e+13
# 3815  10267360  https://www.airbnb.com/rooms/10267360  2.016010e+13
# 3816   9604740   https://www.airbnb.com/rooms/9604740  2.016010e+13
# 3817  10208623  https://www.airbnb.com/rooms/10208623  2.016010e+13
#
#      last_scraped                                 name  \
# 0        4/1/2016         Stylish Queen Anne Apartment
# 1        4/1/2016   Bright & Airy Queen Anne Apartment
# 2        4/1/2016  New Modern House-Amazing water view
# 3        4/1/2016                   Queen Anne Chateau
# 4        4/1/2016       Charming craftsman 3 bdm house
# ...           ...                                  ...
# 3813     4/1/2016   3BR Mountain View House in Seattle
# 3814     4/1/2016    Portage Bay View!-One Bedroom Apt
# 3815     4/1/2016    Private apartment view of Lake WA
# 3816     4/1/2016    Amazing View with Modern Comfort!
# 3817     4/1/2016            Large Lakefront Apartment
#
#                                                 summary  \
# 0                                                   NaN
# 1     Chemically sensitive? We've removed the irrita...
# 2     New modern house built in 2013.  Spectacular s...
# 3     A charming apartment that sits atop Queen Anne...
# 4     Cozy family craftman house in beautiful neighb...
# ...                                                 ...
# 3813  Our 3BR/2BA house boasts incredible views of t...
# 3814  800 square foot 1 bedroom basement apartment w...
# 3815  Very comfortable lower unit. Quiet, charming m...
# 3816  Cozy studio condo in the heart on Madison Park...
# 3817  All hardwood floors, fireplace, 65" TV with Xb...
#
#                                                   space  \
# 0     Make your self at home in this charming one-be...
# 1     Beautiful, hypoallergenic apartment in an extr...
# 2     Our house is modern, light and fresh with a wa...
# 3                                                   NaN
# 4     Cozy family craftman house in beautiful neighb...
# ...                                                 ...
# 3813  Our 3BR/2BA house bright, stylish, and wheelch...
# 3814  This space has a great view of Portage Bay wit...
# 3815                                                NaN
# 3816  Fully furnished unit to accommodate most needs...
# 3817                                                NaN
#
#                                             description experiences_offered  \
# 0     Make your self at home in this charming one-be...                none
# 1     Chemically sensitive? We've removed the irrita...                none
# 2     New modern house built in 2013.  Spectacular s...                none
# 3     A charming apartment that sits atop Queen Anne...                none
# 4     Cozy family craftman house in beautiful neighb...                none
# ...                                                 ...                 ...
# 3813  Our 3BR/2BA house boasts incredible views of t...                none
# 3814  800 square foot 1 bedroom basement apartment w...                none
# 3815  Very comfortable lower unit. Quiet, charming m...                none
# 3816  Cozy studio condo in the heart on Madison Park...                none
# 3817  All hardwood floors, fireplace, 65" TV with Xb...                none
#
#                                   neighborhood_overview  ... Kitchen  \
# 0                                                   NaN  ...    True
# 1     Queen Anne is a wonderful, truly functional vi...  ...    True
# 2     Upper Queen Anne is a charming neighborhood fu...  ...    True
# 3                                                   NaN  ...    True
# 4     We are in the beautiful neighborhood of Queen ...  ...    True
# ...                                                 ...  ...     ...
# 3813  We're located near lots of family fun. Woodlan...  ...    True
# 3814  The neighborhood is a quiet oasis that is clos...  ...    True
# 3815                                                NaN  ...    True
# 3816  Madison Park offers a peaceful slow pace upsca...  ...    True
# 3817                                                NaN  ...    True
#
#      Laundry Facility Pet Friendly   Pool Safety Features Security Features  \
# 0                True        False  False           False             False
# 1                True        False  False            True              True
# 2                True         True  False            True             False
# 3                True        False  False            True              True
# 4               False        False  False            True             False
# ...               ...          ...    ...             ...               ...
# 3813             True        False  False            True             False
# 3814             True        False  False            True             False
# 3815             True         True  False            True              True
# 3816             True        False  False            True             False
# 3817             True         True  False            True              True
#
#       Smoking Allowed Suitable for Events     TV Weather Control
# 0               False               False   True            True
# 1               False               False   True            True
# 2               False               False   True            True
# 3               False               False  False            True
# 4               False               False   True            True
# ...               ...                 ...    ...             ...
# 3813            False               False   True            True
# 3814            False               False   True            True
# 3815            False               False   True            True
# 3816            False               False   True            True
# 3817            False               False   True            True
#
# [3818 rows x 111 columns]

# %%
listings['extra_people']
# Out:
# 0        $5.00
# 1        $0.00
# 2       $25.00
# 3        $0.00
# 4       $15.00
#          ...
# 3813     $0.00
# 3814    $25.00
# 3815    $20.00
# 3816     $0.00
# 3817     $0.00
# Name: extra_people, Length: 3818, dtype: object

# %%
listings['extra_people'] = listings['extra_people'].replace('[\$,]', '', regex=True).astype(float)

# %%
#Check for columns infomation
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Columns: 111 entries, id to Weather Control
# dtypes: bool(19), float64(19), int64(12), object(61)
# memory usage: 2.7+ MB

# %%
#print the unique values for neighborhood
print("Number of neighbourhood :", len(listings["neighbourhood"].unique()))

# neighborhood plot
print(listings["neighbourhood"].value_counts())
sb.catplot(y = "neighbourhood", data = listings, kind = "count")
# Out:
# Number of neighbourhood : 82
# Capitol Hill          351
# Ballard               213
# Belltown              204
# Minor                 192
# Queen Anne            187
#                      ...
# South Beacon Hill       2
# South Park              2
# Fairmount Park          1
# North College Park      1
# Roxhill                 1
# Name: neighbourhood, Length: 81, dtype: int64

# %%
#print the unique values for neighbourhood_cleansed
print("Number of neighbourhood_cleansed :", len(listings["neighbourhood_cleansed"].unique()))

# neighbourhood_cleansed plot
print(listings["neighbourhood_cleansed"].value_counts())
sb.catplot(y = "neighbourhood_cleansed", data = listings, kind = "count")
# Out:
# Number of neighbourhood_cleansed : 87
# Broadway             397
# Belltown             234
# Wallingford          167
# Fremont              158
# Minor                135
#                     ...
# Arbor Heights          5
# Pinehurst              4
# South Beacon Hill      4
# South Park             3
# Roxhill                2
# Name: neighbourhood_cleansed, Length: 87, dtype: int64

# %%
#print the unique values for neighbourhood_group_cleansed
print("Number of neighbourhood_group_cleansed :", len(listings["neighbourhood_group_cleansed"].unique()))

# neighbourhood_group_cleansed plot
print(listings["neighbourhood_group_cleansed"].value_counts())
sb.catplot(y = "neighbourhood_group_cleansed", data = listings, kind = "count")
# Out:
# Number of neighbourhood_group_cleansed : 17
# Other neighborhoods    794
# Capitol Hill           567
# Downtown               530
# Central Area           369
# Queen Anne             295
# Ballard                230
# West Seattle           203
# Rainier Valley         159
# University District    122
# Beacon Hill            118
# Cascade                 89
# Northgate               80
# Delridge                79
# Lake City               67
# Magnolia                61
# Seward Park             44
# Interbay                11
# Name: neighbourhood_group_cleansed, dtype: int64

# %%
#print the unique values for host_neighbourhood
print("Number of host_neighbourhood :", len(listings["host_neighbourhood"].unique()))

# host_neighbourhood plot
print(listings["host_neighbourhood"].value_counts())
sb.catplot(y = "host_neighbourhood", data = listings, kind = "count")
# Out:
# Number of host_neighbourhood : 103
# Capitol Hill          405
# Belltown              254
# Ballard               210
# Minor                 191
# Queen Anne            189
#                      ...
# Huntington Beach        1
# Northwest District      1
# East Village            1
# Kauaʻi                  1
# North Hollywood         1
# Name: host_neighbourhood, Length: 102, dtype: int64

# %%
#print the unique values for zipcode
print("Number of zipcode :", len(listings["zipcode"].unique()))

# zipcode plot
print(listings["zipcode"].value_counts())
sb.catplot(y = "zipcode", data = listings, kind = "count")
# Out:
# Number of zipcode : 29
# 98122        420
# 98103        394
# 98102        339
# 98105        225
# 98109        202
# 98101        201
# 98144        200
# 98121        196
# 98107        180
# 98115        178
# 98112        167
# 98117        164
# 98118        154
# 98119        143
# 98116        112
# 98104         95
# 98125         71
# 98199         66
# 98126         63
# 98106         58
# 98108         56
# 98133         46
# 98136         44
# 98177         19
# 98178          7
# 98134          5
# 98146          5
# 99\n98122      1
# Name: zipcode, dtype: int64

# %%
#In the previous data cleasing part, we have already found that neighbourhood_group_cleansed and neighbourhood_cleansed have no missing value.

# %%
#By plotting the unique categories, we find that neighbourhood_group_cleansed has fewer categories. 
#Therefore, we choose this as criteria for zoning.

# %%
listings.loc[listings.neighbourhood_group_cleansed=='5']
# Out:
# Empty DataFrame
# Columns: [id, listing_url, scrape_id, last_scraped, name, summary, space, description, experiences_offered, neighborhood_overview, notes, transit, thumbnail_url, medium_url, picture_url, xl_picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, street, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, city, state, zipcode, market, smart_location, country_code, country, latitude, longitude, is_location_exact, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, minimum_nights, maximum_nights, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, requires_license, license, jurisdiction_names, instant_bookable, cancellation_policy, require_guest_profile_picture, require_guest_phone_verification, calculated_host_listings_count, reviews_per_month, 24-Hour Check-in, Access Friendly, Breakfast, Essentials, Family/Kid Friendly, Free Parking on Premises, Gym, Hot Tub, ...]
# Index: []
#
# [0 rows x 111 columns]

# %%
listings.loc[listings.zipcode=='t']
# Out:
# Empty DataFrame
# Columns: [id, listing_url, scrape_id, last_scraped, name, summary, space, description, experiences_offered, neighborhood_overview, notes, transit, thumbnail_url, medium_url, picture_url, xl_picture_url, host_id, host_url, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_thumbnail_url, host_picture_url, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, street, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, city, state, zipcode, market, smart_location, country_code, country, latitude, longitude, is_location_exact, property_type, room_type, accommodates, bathrooms, bedrooms, beds, bed_type, amenities, square_feet, price, weekly_price, monthly_price, security_deposit, cleaning_fee, guests_included, extra_people, minimum_nights, maximum_nights, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, requires_license, license, jurisdiction_names, instant_bookable, cancellation_policy, require_guest_profile_picture, require_guest_phone_verification, calculated_host_listings_count, reviews_per_month, 24-Hour Check-in, Access Friendly, Breakfast, Essentials, Family/Kid Friendly, Free Parking on Premises, Gym, Hot Tub, ...]
# Index: []
#
# [0 rows x 111 columns]

# %%
listing_new=listings.drop([1933,1942])
listing_new
# Out:
#             id                            listing_url     scrape_id  \
# 0       241032    https://www.airbnb.com/rooms/241032  2.016010e+13
# 1       953595    https://www.airbnb.com/rooms/953595  2.016010e+13
# 2      3308979   https://www.airbnb.com/rooms/3308979  2.016010e+13
# 3      7421966   https://www.airbnb.com/rooms/7421966  2.016010e+13
# 4       278830    https://www.airbnb.com/rooms/278830  2.016010e+13
# ...        ...                                    ...           ...
# 3813   8101950   https://www.airbnb.com/rooms/8101950  2.016010e+13
# 3814   8902327   https://www.airbnb.com/rooms/8902327  2.016010e+13
# 3815  10267360  https://www.airbnb.com/rooms/10267360  2.016010e+13
# 3816   9604740   https://www.airbnb.com/rooms/9604740  2.016010e+13
# 3817  10208623  https://www.airbnb.com/rooms/10208623  2.016010e+13
#
#      last_scraped                                 name  \
# 0        4/1/2016         Stylish Queen Anne Apartment
# 1        4/1/2016   Bright & Airy Queen Anne Apartment
# 2        4/1/2016  New Modern House-Amazing water view
# 3        4/1/2016                   Queen Anne Chateau
# 4        4/1/2016       Charming craftsman 3 bdm house
# ...           ...                                  ...
# 3813     4/1/2016   3BR Mountain View House in Seattle
# 3814     4/1/2016    Portage Bay View!-One Bedroom Apt
# 3815     4/1/2016    Private apartment view of Lake WA
# 3816     4/1/2016    Amazing View with Modern Comfort!
# 3817     4/1/2016            Large Lakefront Apartment
#
#                                                 summary  \
# 0                                                   NaN
# 1     Chemically sensitive? We've removed the irrita...
# 2     New modern house built in 2013.  Spectacular s...
# 3     A charming apartment that sits atop Queen Anne...
# 4     Cozy family craftman house in beautiful neighb...
# ...                                                 ...
# 3813  Our 3BR/2BA house boasts incredible views of t...
# 3814  800 square foot 1 bedroom basement apartment w...
# 3815  Very comfortable lower unit. Quiet, charming m...
# 3816  Cozy studio condo in the heart on Madison Park...
# 3817  All hardwood floors, fireplace, 65" TV with Xb...
#
#                                                   space  \
# 0     Make your self at home in this charming one-be...
# 1     Beautiful, hypoallergenic apartment in an extr...
# 2     Our house is modern, light and fresh with a wa...
# 3                                                   NaN
# 4     Cozy family craftman house in beautiful neighb...
# ...                                                 ...
# 3813  Our 3BR/2BA house bright, stylish, and wheelch...
# 3814  This space has a great view of Portage Bay wit...
# 3815                                                NaN
# 3816  Fully furnished unit to accommodate most needs...
# 3817                                                NaN
#
#                                             description experiences_offered  \
# 0     Make your self at home in this charming one-be...                none
# 1     Chemically sensitive? We've removed the irrita...                none
# 2     New modern house built in 2013.  Spectacular s...                none
# 3     A charming apartment that sits atop Queen Anne...                none
# 4     Cozy family craftman house in beautiful neighb...                none
# ...                                                 ...                 ...
# 3813  Our 3BR/2BA house boasts incredible views of t...                none
# 3814  800 square foot 1 bedroom basement apartment w...                none
# 3815  Very comfortable lower unit. Quiet, charming m...                none
# 3816  Cozy studio condo in the heart on Madison Park...                none
# 3817  All hardwood floors, fireplace, 65" TV with Xb...                none
#
#                                   neighborhood_overview  ... Kitchen  \
# 0                                                   NaN  ...    True
# 1     Queen Anne is a wonderful, truly functional vi...  ...    True
# 2     Upper Queen Anne is a charming neighborhood fu...  ...    True
# 3                                                   NaN  ...    True
# 4     We are in the beautiful neighborhood of Queen ...  ...    True
# ...                                                 ...  ...     ...
# 3813  We're located near lots of family fun. Woodlan...  ...    True
# 3814  The neighborhood is a quiet oasis that is clos...  ...    True
# 3815                                                NaN  ...    True
# 3816  Madison Park offers a peaceful slow pace upsca...  ...    True
# 3817                                                NaN  ...    True
#
#      Laundry Facility Pet Friendly   Pool Safety Features Security Features  \
# 0                True        False  False           False             False
# 1                True        False  False            True              True
# 2                True         True  False            True             False
# 3                True        False  False            True              True
# 4               False        False  False            True             False
# ...               ...          ...    ...             ...               ...
# 3813             True        False  False            True             False
# 3814             True        False  False            True             False
# 3815             True         True  False            True              True
# 3816             True        False  False            True             False
# 3817             True         True  False            True              True
#
#       Smoking Allowed Suitable for Events     TV Weather Control
# 0               False               False   True            True
# 1               False               False   True            True
# 2               False               False   True            True
# 3               False               False  False            True
# 4               False               False   True            True
# ...               ...                 ...    ...             ...
# 3813            False               False   True            True
# 3814            False               False   True            True
# 3815            False               False   True            True
# 3816            False               False   True            True
# 3817            False               False   True            True
#
# [3816 rows x 111 columns]

# %%
#print the unique values for neighbourhood_group_cleansed
print("Number of neighbourhood_group_cleansed :", len(listing_new["neighbourhood_group_cleansed"].unique()))

# neighbourhood_group_cleansed plot
print(listing_new["neighbourhood_group_cleansed"].value_counts())
sb.catplot(y = "neighbourhood_group_cleansed", data = listings, kind = "count")
# Out:
# Number of neighbourhood_group_cleansed : 17
# Other neighborhoods    794
# Capitol Hill           567
# Downtown               530
# Central Area           369
# Queen Anne             295
# Ballard                230
# West Seattle           203
# Rainier Valley         159
# University District    122
# Beacon Hill            116
# Cascade                 89
# Northgate               80
# Delridge                79
# Lake City               67
# Magnolia                61
# Seward Park             44
# Interbay                11
# Name: neighbourhood_group_cleansed, dtype: int64

# %%
# group data by their neighbourhood_group_cleansed attributes.

# %%
Capitol_Hill=[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Capitol Hill':
        Capitol_Hill.append(row)
Capitol_Hill=pd.DataFrame(Capitol_Hill, columns=row._fields)
Capitol_Hill.price.describe()
# Out:
# count         567
# unique        136
# top       $100.00
# freq           36
# Name: price, dtype: object

# %%
Other_neighborhoods =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Other neighborhoods':
        Other_neighborhoods.append(row)
Other_neighborhoods=pd.DataFrame(Other_neighborhoods, columns=row._fields)
Other_neighborhoods.price.describe()
# Out:
# count         794
# unique        148
# top       $100.00
# freq           39
# Name: price, dtype: object

# %%
Downtown=[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Downtown':
        Downtown.append(row)
Downtown=pd.DataFrame(Downtown, columns=row._fields)
Downtown.price.describe()
# Out:
# count         530
# unique        137
# top       $150.00
# freq           33
# Name: price, dtype: object

# %%
Central_Area =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Central Area':
        Central_Area.append(row)
Central_Area=pd.DataFrame(Central_Area, columns=row._fields)
Central_Area.price.describe()
# Out:
# count        369
# unique       108
# top       $90.00
# freq          24
# Name: price, dtype: object

# %%
Queen_Anne=[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Queen Anne':
        Queen_Anne.append(row)
Queen_Anne=pd.DataFrame(Queen_Anne, columns=row._fields)
Queen_Anne.price.describe()
# Out:
# count         295
# unique        107
# top       $150.00
# freq           16
# Name: price, dtype: object

# %%
Ballard =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Ballard':
        Ballard.append(row)
Ballard=pd.DataFrame(Ballard, columns=row._fields)
Ballard.price.describe()
# Out:
# count        230
# unique        78
# top       $80.00
# freq          12
# Name: price, dtype: object

# %%
West_Seattle =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='West Seattle':
        West_Seattle.append(row)
West_Seattle=pd.DataFrame(West_Seattle, columns=row._fields)
West_Seattle.price.describe()
# Out:
# count        203
# unique        79
# top       $75.00
# freq          11
# Name: price, dtype: object

# %%
Rainier_Valley =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Rainier Valley':
        Rainier_Valley.append(row)
Rainier_Valley=pd.DataFrame(Rainier_Valley, columns=row._fields)
Rainier_Valley.price.describe()
# Out:
# count        159
# unique        65
# top       $65.00
# freq          11
# Name: price, dtype: object

# %%
University_District =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='University District':
        University_District.append(row)
University_District=pd.DataFrame(University_District, columns=row._fields)
University_District.price.describe()
# Out:
# count        122
# unique        55
# top       $85.00
# freq           9
# Name: price, dtype: object

# %%
Beacon_Hill =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Beacon Hill':
        Beacon_Hill.append(row)
Beacon_Hill=pd.DataFrame(Beacon_Hill, columns=row._fields)
Beacon_Hill.price.describe()
# Out:
# count        116
# unique        55
# top       $60.00
# freq          11
# Name: price, dtype: object

# %%
Cascade =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Cascade':
        Cascade.append(row)
Cascade=pd.DataFrame(Cascade, columns=row._fields)
Cascade.price.describe()
# Out:
# count          89
# unique         47
# top       $100.00
# freq            6
# Name: price, dtype: object

# %%
Northgate =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Northgate':
        Northgate.append(row)
Northgate=pd.DataFrame(Northgate, columns=row._fields)
Northgate.price.describe()
# Out:
# count         80
# unique        46
# top       $55.00
# freq           6
# Name: price, dtype: object

# %%
Delridge =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Delridge':
        Delridge.append(row)
Delridge=pd.DataFrame(Delridge, columns=row._fields)
Delridge.price.describe()
# Out:
# count         79
# unique        37
# top       $55.00
# freq           7
# Name: price, dtype: object

# %%
Lake_City =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Lake City':
        Lake_City.append(row)
Lake_City=pd.DataFrame(Lake_City, columns=row._fields)
Lake_City.price.describe()
# Out:
# count         67
# unique        40
# top       $60.00
# freq           6
# Name: price, dtype: object

# %%
Magnolia =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Magnolia':
        Magnolia.append(row)
Magnolia=pd.DataFrame(Magnolia, columns=row._fields)
Magnolia.price.describe()
# Out:
# count          61
# unique         41
# top       $150.00
# freq            4
# Name: price, dtype: object

# %%
Seward_Park =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Seward Park':
        Seward_Park.append(row)
Seward_Park=pd.DataFrame(Seward_Park, columns=row._fields)
Seward_Park.price.describe()
# Out:
# count         44
# unique        32
# top       $65.00
# freq           4
# Name: price, dtype: object

# %%
Interbay =[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Interbay':
        Interbay.append(row)
Interbay=pd.DataFrame(Interbay, columns=row._fields)
Interbay.price.describe()
# Out:
# count          11
# unique          8
# top       $150.00
# freq            3
# Name: price, dtype: object

# %%
# create an array of dataframes
cities=[Other_neighborhoods,Capitol_Hill,Downtown,Central_Area,Queen_Anne,Ballard,West_Seattle,Rainier_Valley,University_District,Beacon_Hill,Cascade,Northgate,Delridge,Lake_City,Magnolia, Seward_Park, Interbay]

# %%
# We can divide cities based on the mean value  
#mean of price >150-----Tier_1
#100<mean of price <150-----Tier_2
#mean of price <100-----Tier_3

# %%
#Create 3 empty dataframes
Tier_1=pd.DataFrame(columns=row._fields)
Tier_2=pd.DataFrame(columns=row._fields)
Tier_3=pd.DataFrame(columns=row._fields)
#group different cities according to the mean value of price.
for i in cities:
    #print(i)
    if(i.price.mean()>150):
        Tier_1=Tier_1.append(i)
    if(i.price.mean()<150 and i.price.mean()>100):
        Tier_2= Tier_2.append(i)
    if(i.price.mean()<100):
        Tier_3=Tier_3.append(i)
# For checking

Tier_1.price.describe()
Tier_2.price.describe()
Tier_3.price.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1302         try:
# -> 1303             x = float(x)
#    1304         except ValueError:
#
# ValueError: could not convert string to float: '$300.00$150.00$149.00$75.00$95.00$100.00$250.00$105.00$74.00$140.00$130.00$110.00$199.00$209.00$100.00$110.00$104.00$200.00$99.00$90.00$135.00$122.00$80.00$158.00$90.00$100.00$89.00$125.00$42.00$65.00$100.00$40.00$185.00$40.00$70.00$40.00$70.00$110.00$99.00$680.00$195.00$55.00$90.00$119.00$175.00$65.00$75.00$126.00$70.00$90.00$129.00$225.00$40.00$50.00$40.00$40.00$95.00$175.00$160.00$40.00$40.00$120.00$66.00$55.00$350.00$85.00$175.00$105.00$55.00$150.00$40.00$59.00$80.00$200.00$60.00$59.00$575.00$40.00$139.00$70.00$85.00$259.00$39.00$70.00$166.00$99.00$110.00$100.00$250.00$150.00$200.00$95.00$40.00$215.00$110.00$249.00$295.00$90.00$40.00$85.00$40.00$40.00$245.00$130.00$210.00$439.00$90.00$95.00$109.00$40.00$175.00$80.00$105.00$400.00$100.00$40.00$160.00$55.00$55.00$150.00$55.00$95.00$155.00$55.00$40.00$250.00$145.00$54.00$99.00$254.00$100.00$65.00$150.00$140.00$45.00$74.00$60.00$350.00$135.00$85.00$310.00$40.00$215.00$245.00$65.00$85.00$95.00$57.00$75.00$120.00$120.00$40.00$490.00$50.00$200.00$40.00$255.00$95.00$160.00$55.00$85.00$325.00$144.00$100.00$115.00$55.00$95.00$109.00$60.00$249.00$250.00$100.00$74.00$235.00$99.00$96.00$92.00$85.00$55.00$55.00$80.00$195.00$145.00$180.00$50.00$160.00$140.00$140.00$40.00$145.00$225.00$325.00$199.00$450.00$175.00$550.00$149.00$130.00$85.00$300.00$79.00$59.00$140.00$60.00$215.00$100.00$40.00$99.00$45.00$75.00$119.00$99.00$225.00$85.00$135.00$335.00$79.00$90.00$111.00$110.00$325.00$70.00$28.00$65.00$69.00$41.00$42.00$100.00$100.00$45.00$65.00$170.00$119.00$100.00$114.00$100.00$68.00$275.00$35.00$75.00$95.00$65.00$150.00$25.00$265.00$320.00$150.00$280.00$80.00$85.00$215.00$120.00$105.00$90.00$125.00$105.00$98.00$44.00$34.00$50.00$85.00$62.00$49.00$50.00$50.00$70.00$40.00$40.00$38.00$26.00$25.00$49.00$129.00$175.00$42.00$126.00$299.00$99.00$175.00$125.00$120.00$42.00$56.00$55.00$55.00$235.00$100.00$60.00$67.00$95.00$115.00$50.00$199.00$86.00$175.00$55.00$68.00$60.00$90.00$139.00$51.00$50.00$115.00$80.00$95.00$85.00$75.00$100.00$63.00$100.00$135.00$125.00$69.00$280.00$160.00$75.00$98.00$109.00$125.00$225.00$69.00$75.00$300.00$60.00$43.00$85.00$110.00$52.00$100.00$50.00$35.00$66.00$99.00$89.00$150.00$90.00$150.00$110.00$120.00$49.00$244.00$125.00$175.00$85.00$115.00$98.00$109.00$28.00$39.00$63.00$35.00$42.00$29.00$70.00$74.00$75.00$85.00$50.00$125.00$93.00$86.00$80.00$280.00$138.00$100.00$45.00$39.00$127.00$110.00$40.00$40.00$90.00$125.00$39.00$80.00$325.00$95.00$115.00$245.00$69.00$129.00$28.00$49.00$110.00$105.00$38.00$130.00$39.00$80.00$110.00$100.00$50.00$75.00$85.00$70.00$95.00$50.00$115.00$45.00$60.00$95.00$39.00$88.00$175.00$80.00$35.00$84.00$49.00$196.00$55.00$66.00$65.00$60.00$295.00$79.00$250.00$58.00$250.00$50.00$89.00$47.00$189.00$175.00$95.00$80.00$95.00$65.00$150.00$94.00$109.00$62.00$150.00$185.00$64.00$100.00$125.00$45.00$180.00$60.00$130.00$65.00$80.00$105.00$40.00$93.00$76.00$100.00$105.00$82.00$209.00$109.00$110.00$1,000.00$60.00$80.00$90.00$125.00$110.00$86.00$165.00$149.00$84.00$139.00$33.00$129.00$59.00$90.00$150.00$94.00$39.00$65.00$65.00$75.00$80.00$100.00$98.00$299.00$250.00$175.00$65.00$75.00$100.00$60.00$48.00$48.00$60.00$125.00$200.00$210.00$85.00$75.00$75.00$80.00$180.00$240.00$49.00$275.00$95.00$108.00$150.00$75.00$99.00$90.00$50.00$170.00$45.00$39.00$78.00$99.00$60.00$65.00$90.00$64.00$190.00$39.00$95.00$100.00$135.00$87.00$97.00$78.00$150.00$95.00$375.00$150.00$325.00$60.00$50.00$120.00$88.00$150.00$195.00$50.00$250.00$87.00$207.00$70.00$100.00$175.00$165.00$120.00$239.00$200.00$135.00$155.00$95.00$78.00$50.00$90.00$151.00$75.00$160.00$189.00$85.00$112.00$400.00$175.00$100.00$350.00$150.00$55.00$95.00$80.00$50.00$95.00$175.00$50.00$190.00$99.00$145.00$90.00$349.00$150.00$105.00$95.00$85.00$52.00$105.00$100.00$110.00$67.00$75.00$69.00$96.00$60.00$95.00$100.00$55.00$130.00$125.00$300.00$200.00$400.00$165.00$117.00$85.00$115.00$62.00$100.00$100.00$60.00$185.00$99.00$200.00$125.00$60.00$100.00$55.00$70.00$90.00$50.00$99 ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1306             try:
# -> 1307                 x = complex(x)
#    1308             except ValueError:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-2912ae03feae> in <module>
#       6 for i in cities:
#       7     #print(i)
# ----> 8     if(i.price.mean()>150):
#       9         Tier_1=Tier_1.append(i)
#      10     if(i.price.mean()<150 and i.price.mean()>100):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11213             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11214         return self._reduce(
# > 11215             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11216         )
#   11217
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      67             try:
#      68                 with np.errstate(invalid="ignore"):
# ---> 69                     return f(*args, **kwargs)
#      70             except ValueError as e:
#      71                 # we want to transform an object array
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     123                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     124             else:
# --> 125                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126
#     127             return result
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     540         dtype_count = dtype
#     541     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 542     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     543
#     544     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1308             except ValueError:
#    1309                 # e.g. "foo"
# -> 1310                 raise TypeError(f"Could not convert {x} to numeric")
#    1311     return x
#    1312
#
# TypeError: Could not convert $300.00$150.00$149.00$75.00$95.00$100.00$250.00$105.00$74.00$140.00$130.00$110.00$199.00$209.00$100.00$110.00$104.00$200.00$99.00$90.00$135.00$122.00$80.00$158.00$90.00$100.00$89.00$125.00$42.00$65.00$100.00$40.00$185.00$40.00$70.00$40.00$70.00$110.00$99.00$680.00$195.00$55.00$90.00$119.00$175.00$65.00$75.00$126.00$70.00$90.00$129.00$225.00$40.00$50.00$40.00$40.00$95.00$175.00$160.00$40.00$40.00$120.00$66.00$55.00$350.00$85.00$175.00$105.00$55.00$150.00$40.00$59.00$80.00$200.00$60.00$59.00$575.00$40.00$139.00$70.00$85.00$259.00$39.00$70.00$166.00$99.00$110.00$100.00$250.00$150.00$200.00$95.00$40.00$215.00$110.00$249.00$295.00$90.00$40.00$85.00$40.00$40.00$245.00$130.00$210.00$439.00$90.00$95.00$109.00$40.00$175.00$80.00$105.00$400.00$100.00$40.00$160.00$55.00$55.00$150.00$55.00$95.00$155.00$55.00$40.00$250.00$145.00$54.00$99.00$254.00$100.00$65.00$150.00$140.00$45.00$74.00$60.00$350.00$135.00$85.00$310.00$40.00$215.00$245.00$65.00$85.00$95.00$57.00$75.00$120.00$120.00$40.00$490.00$50.00$200.00$40.00$255.00$95.00$160.00$55.00$85.00$325.00$144.00$100.00$115.00$55.00$95.00$109.00$60.00$249.00$250.00$100.00$74.00$235.00$99.00$96.00$92.00$85.00$55.00$55.00$80.00$195.00$145.00$180.00$50.00$160.00$140.00$140.00$40.00$145.00$225.00$325.00$199.00$450.00$175.00$550.00$149.00$130.00$85.00$300.00$79.00$59.00$140.00$60.00$215.00$100.00$40.00$99.00$45.00$75.00$119.00$99.00$225.00$85.00$135.00$335.00$79.00$90.00$111.00$110.00$325.00$70.00$28.00$65.00$69.00$41.00$42.00$100.00$100.00$45.00$65.00$170.00$119.00$100.00$114.00$100.00$68.00$275.00$35.00$75.00$95.00$65.00$150.00$25.00$265.00$320.00$150.00$280.00$80.00$85.00$215.00$120.00$105.00$90.00$125.00$105.00$98.00$44.00$34.00$50.00$85.00$62.00$49.00$50.00$50.00$70.00$40.00$40.00$38.00$26.00$25.00$49.00$129.00$175.00$42.00$126.00$299.00$99.00$175.00$125.00$120.00$42.00$56.00$55.00$55.00$235.00$100.00$60.00$67.00$95.00$115.00$50.00$199.00$86.00$175.00$55.00$68.00$60.00$90.00$139.00$51.00$50.00$115.00$80.00$95.00$85.00$75.00$100.00$63.00$100.00$135.00$125.00$69.00$280.00$160.00$75.00$98.00$109.00$125.00$225.00$69.00$75.00$300.00$60.00$43.00$85.00$110.00$52.00$100.00$50.00$35.00$66.00$99.00$89.00$150.00$90.00$150.00$110.00$120.00$49.00$244.00$125.00$175.00$85.00$115.00$98.00$109.00$28.00$39.00$63.00$35.00$42.00$29.00$70.00$74.00$75.00$85.00$50.00$125.00$93.00$86.00$80.00$280.00$138.00$100.00$45.00$39.00$127.00$110.00$40.00$40.00$90.00$125.00$39.00$80.00$325.00$95.00$115.00$245.00$69.00$129.00$28.00$49.00$110.00$105.00$38.00$130.00$39.00$80.00$110.00$100.00$50.00$75.00$85.00$70.00$95.00$50.00$115.00$45.00$60.00$95.00$39.00$88.00$175.00$80.00$35.00$84.00$49.00$196.00$55.00$66.00$65.00$60.00$295.00$79.00$250.00$58.00$250.00$50.00$89.00$47.00$189.00$175.00$95.00$80.00$95.00$65.00$150.00$94.00$109.00$62.00$150.00$185.00$64.00$100.00$125.00$45.00$180.00$60.00$130.00$65.00$80.00$105.00$40.00$93.00$76.00$100.00$105.00$82.00$209.00$109.00$110.00$1,000.00$60.00$80.00$90.00$125.00$110.00$86.00$165.00$149.00$84.00$139.00$33.00$129.00$59.00$90.00$150.00$94.00$39.00$65.00$65.00$75.00$80.00$100.00$98.00$299.00$250.00$175.00$65.00$75.00$100.00$60.00$48.00$48.00$60.00$125.00$200.00$210.00$85.00$75.00$75.00$80.00$180.00$240.00$49.00$275.00$95.00$108.00$150.00$75.00$99.00$90.00$50.00$170.00$45.00$39.00$78.00$99.00$60.00$65.00$90.00$64.00$190.00$39.00$95.00$100.00$135.00$87.00$97.00$78.00$150.00$95.00$375.00$150.00$325.00$60.00$50.00$120.00$88.00$150.00$195.00$50.00$250.00$87.00$207.00$70.00$100.00$175.00$165.00$120.00$239.00$200.00$135.00$155.00$95.00$78.00$50.00$90.00$151.00$75.00$160.00$189.00$85.00$112.00$400.00$175.00$100.00$350.00$150.00$55.00$95.00$80.00$50.00$95.00$175.00$50.00$190.00$99.00$145.00$90.00$349.00$150.00$105.00$95.00$85.00$52.00$105.00$100.00$110.00$67.00$75.00$69.00$96.00$60.00$95.00$100.00$55.00$130.00$125.00$300.00$200.00$400.00$165.00$117.00$85.00$115.00$62.00$100.00$100.00$60.00$185.00$99.00$200.00$125.00$60.00$100.00$55.00$70.00$90.00$50.00$99.00$70.00$65.00$90. ...

# %%
#produce new csv files.
Tier_1.to_csv('..\dataset_filter\Tier_1.csv',index=False)
Tier_2.to_csv('..\dataset_filter\Tier_2.csv',index=False)
Tier_3.to_csv('..\dataset_filter\Tier_3.csv',index=False)

# %%
# We found that there are 7 districts in Seattle, so we put different neighbourhoods into different districts.
District_1=[]
District_2=[]
District_3=[]
District_4=[]
District_5=[]
District_6=[]
District_7=[]
Other_neighborhoods=[]
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Delridge':
        District_1.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Capitol Hill':
        District_3.append(row)

for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Downtown':
        District_7.append(row)       
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Central Area' :
        District_3.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Queen Anne':
        District_7.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Ballard':
        District_6.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='West Seattle':
        District_1.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Rainier Valley':
        District_2.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='University District':
        District_4.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Beacon Hill':
        District_2.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Cascade':
        District_7.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Northgate':
        District_5.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Lake City':
        District_5.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Magnolia':
        District_7.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Seward Park':
        District_2.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Interbay':
        District_7.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='North Beacon Hill':
        District_3.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='S Morgan St, Seattle, WA 98108, United States':
        Other_neighborhoods.append(row)
for row in  listing_new.itertuples():
   if row.neighbourhood_group_cleansed=='Other neighborhoods':
        Other_neighborhoods.append(row)
#convert tuples to corresponding dataframes.       

District_1 = pd.DataFrame(District_1, columns=row._fields)
District_2 = pd.DataFrame(District_2, columns=row._fields)
District_3 = pd.DataFrame(District_3, columns=row._fields)
District_4 = pd.DataFrame(District_4, columns=row._fields)
District_5 = pd.DataFrame(District_5, columns=row._fields)
District_6 = pd.DataFrame(District_6, columns=row._fields)
District_7 = pd.DataFrame(District_7, columns=row._fields)
Other_neighborhoods = pd.DataFrame(Other_neighborhoods, columns=row._fields)

print(type(District_1))
print(District_1.shape)
District_1.head()

print(type(District_2))
print(District_2.shape)
District_2.head()

print(type(District_3))
print(District_3.shape)
District_3.head()

print(type(District_4))
print(District_4.shape)
District_4.head()

print(type(District_5))
print(District_5.shape)
District_5.head()

print(type(District_6))
print(District_6.shape)
District_6.head()

print(type(District_7))
print(District_7.shape)
District_7.head()

print(type(Other_neighborhoods))
print(Other_neighborhoods.shape)
Other_neighborhoods.head()
"""
#produce new csv files.
District_1.to_csv('..\dataset_filter\District_1.csv',index=False)
District_2.to_csv('..\dataset_filter\District_2.csv',index=False)
District_3.to_csv('..\dataset_filter\District_3.csv',index=False)
District_4.to_csv('..\dataset_filter\District_4.csv',index=False)
District_5.to_csv('..\dataset_filter\District_5.csv',index=False)
District_6.to_csv('..\dataset_filter\District_6.csv',index=False)
District_7.to_csv('..\dataset_filter\District_7.csv',index=False)
Other_neighborhoods.to_csv('..\dataset_filter\Other_neighborhoods.csv',index=False)
        """
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (282, 112)
# <class 'pandas.core.frame.DataFrame'>
# (319, 112)
# <class 'pandas.core.frame.DataFrame'>
# (936, 112)
# <class 'pandas.core.frame.DataFrame'>
# (122, 112)
# <class 'pandas.core.frame.DataFrame'>
# (147, 112)
# <class 'pandas.core.frame.DataFrame'>
# (230, 112)
# <class 'pandas.core.frame.DataFrame'>
# (986, 112)
# <class 'pandas.core.frame.DataFrame'>
# (794, 112)
# "\n#produce new csv files.\nDistrict_1.to_csv('..\\dataset_filter\\District_1.csv',index=False)\nDistrict_2.to_csv('..\\dataset_filter\\District_2.csv',index=False)\nDistrict_3.to_csv('..\\dataset_filter\\District_3.csv',index=False)\nDistrict_4.to_csv('..\\dataset_filter\\District_4.csv',index=False)\nDistrict_5.to_csv('..\\dataset_filter\\District_5.csv',index=False)\nDistrict_6.to_csv('..\\dataset_filter\\District_6.csv',index=False)\nDistrict_7.to_csv('..\\dataset_filter\\District_7.csv',index=False)\nOther_neighborhoods.to_csv('..\\dataset_filter\\Other_neighborhoods.csv',index=False)\n        "

# %%
# We find that houses in District1,District2,District4 and District5 are not so many, therefore, we cancatenate them into District_1245.
District_1245=pd.concat([District_1,District_2,District_4,District_5])

# %%
District_1245
# Out:
#      Index       id                           listing_url     scrape_id  \
# 0     2158  3279728  https://www.airbnb.com/rooms/3279728  2.016010e+13
# 1     2159  8446766  https://www.airbnb.com/rooms/8446766  2.016010e+13
# 2     2160  9733841  https://www.airbnb.com/rooms/9733841  2.016010e+13
# 3     2161  5852034  https://www.airbnb.com/rooms/5852034  2.016010e+13
# 4     2162  1851837  https://www.airbnb.com/rooms/1851837  2.016010e+13
# ..     ...      ...                                   ...           ...
# 142   3269  6438099  https://www.airbnb.com/rooms/6438099  2.016010e+13
# 143   3270  7650458  https://www.airbnb.com/rooms/7650458  2.016010e+13
# 144   3271  7219541  https://www.airbnb.com/rooms/7219541  2.016010e+13
# 145   3272  4092037  https://www.airbnb.com/rooms/4092037  2.016010e+13
# 146   3273   475361   https://www.airbnb.com/rooms/475361  2.016010e+13
#
#     last_scraped                                 name  \
# 0       4/1/2016           Stylish West Seattle 3BD
# 1       4/1/2016       Beautiful West Seattle Getaway
# 2       4/1/2016  Private, Cozy, Convenient W Seattle
# 3       4/1/2016         Maiden Mansion - Tiny House
# 4       4/1/2016   Awesome cozy One Bedroom Apartment
# ..           ...                                  ...
# 142     4/1/2016       Private room with private bath
# 143     4/1/2016   Large, Beautiful, Affordable Condo
# 144     4/1/2016   A beautiful house with a lake view
# 145     4/1/2016          Modern 3 BR home in Seattle
# 146     4/1/2016  NE Seattle Artist Treehouse Suite!
#
#                                                summary  \
# 0    Recently remodeled mid century home is squarel...
# 1    Clean comfortable room, queen size memory foam...
# 2    Private bed and bath! Room features wonderful ...
# 3    I designed and built this tiny house to be a c...
# 4    Enjoy the-lower level of our home a great livi...
# ..                                                 ...
# 142  Private room with private bath and patio deck ...
# 143  Condo is beautifully appointed & comfortable. ...
# 144  Neighborhood, Seattle, near NE 123rd St and Sa...
# 145  Enjoy a brand-new modern home in Seattle just ...
# 146  Friendly, joyful, light: large space, part art...
#
#                                                  space  \
# 0    This is a clean, comfortable, safe and secure,...
# 1    You can bring your pets, under 10 minutes to d...
# 2    This space was designed to give you maximum co...
# 3    I designed and built this tiny house on wheels...
# 4    Enjoy the-lower level of our home a great livi...
# ..                                                 ...
# 142  Please excuse the mess in the picture. The act...
# 143   This is a top floor condo in a 16 unit building.
# 144                                                NaN
# 145  Enjoy a brand-new, modern home (occupied since...
# 146  Please note: Smokers need not apply!  :-D 1.  ...
#
#                                            description experiences_offered  \
# 0    Recently remodeled mid century home is squarel...                none
# 1    Clean comfortable room, queen size memory foam...                none
# 2    Private bed and bath! Room features wonderful ...                none
# 3    I designed and built this tiny house to be a c...                none
# 4    Enjoy the-lower level of our home a great livi...                none
# ..                                                 ...                 ...
# 142  Private room with private bath and patio deck ...                none
# 143  Condo is beautifully appointed & comfortable. ...                none
# 144  Neighborhood, Seattle, near NE 123rd St and Sa...                none
# 145  Enjoy a brand-new modern home in Seattle just ...                none
# 146  Friendly, joyful, light: large space, part art...                none
#
#      ... Kitchen   _103   _104   Pool   _106   _107   _108   _109     TV  _111
# 0    ...    True   True  False  False   True  False  False  False   True  True
# 1    ...    True   True   True  False   True  False   True   True   True  True
# 2    ...   False   True   True  False   True  False  False  False   True  True
# 3    ...    True   True  False  False   True   True  False  False  False  True
# 4    ...    True   True  False  False  False  False  False  False   True  True
# ..   ...     ...    ...    ...    ...    ...    ...    ...    ...    ...   ...
# 142  ...    True  False  False  False   True  False  False  False   True  True
# 143  ...    True   True  False  False   True   True  False  False   True  True
# 144  ...   False   True  False  False   True  False  False  False  False  True
# 145  ...    True   True   True  False   True  False  False  False   True  True
# 146  ...   False   True  False  False  False  False  False  False   True  True
#
# [870 rows x 112 columns]

# %%
District_1245_new=District_1245.assign(District_1245="",District_3="",District_6="",District_7="",Other_neighborhoods="")
District_3_new=District_3.assign(District_1245="",District_3="",District_6="",District_7="",Other_neighborhoods="")
District_6_new=District_6.assign(District_1245="",District_3="",District_6="",District_7="",Other_neighborhoods="")
District_7_new=District_7.assign(District_1245="",District_3="",District_6="",District_7="",Other_neighborhoods="")
Other_neighborhoods_new=Other_neighborhoods.assign(District_1245="",District_3="",District_6="",District_7="",Other_neighborhoods="")

# %%
#Chcek
District_1245_new
# Out:
#      Index       id                           listing_url     scrape_id  \
# 0     2158  3279728  https://www.airbnb.com/rooms/3279728  2.016010e+13
# 1     2159  8446766  https://www.airbnb.com/rooms/8446766  2.016010e+13
# 2     2160  9733841  https://www.airbnb.com/rooms/9733841  2.016010e+13
# 3     2161  5852034  https://www.airbnb.com/rooms/5852034  2.016010e+13
# 4     2162  1851837  https://www.airbnb.com/rooms/1851837  2.016010e+13
# ..     ...      ...                                   ...           ...
# 142   3269  6438099  https://www.airbnb.com/rooms/6438099  2.016010e+13
# 143   3270  7650458  https://www.airbnb.com/rooms/7650458  2.016010e+13
# 144   3271  7219541  https://www.airbnb.com/rooms/7219541  2.016010e+13
# 145   3272  4092037  https://www.airbnb.com/rooms/4092037  2.016010e+13
# 146   3273   475361   https://www.airbnb.com/rooms/475361  2.016010e+13
#
#     last_scraped                                 name  \
# 0       4/1/2016           Stylish West Seattle 3BD
# 1       4/1/2016       Beautiful West Seattle Getaway
# 2       4/1/2016  Private, Cozy, Convenient W Seattle
# 3       4/1/2016         Maiden Mansion - Tiny House
# 4       4/1/2016   Awesome cozy One Bedroom Apartment
# ..           ...                                  ...
# 142     4/1/2016       Private room with private bath
# 143     4/1/2016   Large, Beautiful, Affordable Condo
# 144     4/1/2016   A beautiful house with a lake view
# 145     4/1/2016          Modern 3 BR home in Seattle
# 146     4/1/2016  NE Seattle Artist Treehouse Suite!
#
#                                                summary  \
# 0    Recently remodeled mid century home is squarel...
# 1    Clean comfortable room, queen size memory foam...
# 2    Private bed and bath! Room features wonderful ...
# 3    I designed and built this tiny house to be a c...
# 4    Enjoy the-lower level of our home a great livi...
# ..                                                 ...
# 142  Private room with private bath and patio deck ...
# 143  Condo is beautifully appointed & comfortable. ...
# 144  Neighborhood, Seattle, near NE 123rd St and Sa...
# 145  Enjoy a brand-new modern home in Seattle just ...
# 146  Friendly, joyful, light: large space, part art...
#
#                                                  space  \
# 0    This is a clean, comfortable, safe and secure,...
# 1    You can bring your pets, under 10 minutes to d...
# 2    This space was designed to give you maximum co...
# 3    I designed and built this tiny house on wheels...
# 4    Enjoy the-lower level of our home a great livi...
# ..                                                 ...
# 142  Please excuse the mess in the picture. The act...
# 143   This is a top floor condo in a 16 unit building.
# 144                                                NaN
# 145  Enjoy a brand-new, modern home (occupied since...
# 146  Please note: Smokers need not apply!  :-D 1.  ...
#
#                                            description experiences_offered  \
# 0    Recently remodeled mid century home is squarel...                none
# 1    Clean comfortable room, queen size memory foam...                none
# 2    Private bed and bath! Room features wonderful ...                none
# 3    I designed and built this tiny house to be a c...                none
# 4    Enjoy the-lower level of our home a great livi...                none
# ..                                                 ...                 ...
# 142  Private room with private bath and patio deck ...                none
# 143  Condo is beautifully appointed & comfortable. ...                none
# 144  Neighborhood, Seattle, near NE 123rd St and Sa...                none
# 145  Enjoy a brand-new modern home in Seattle just ...                none
# 146  Friendly, joyful, light: large space, part art...                none
#
#      ...   _107   _108   _109     TV  _111 District_1245 District_3  \
# 0    ...  False  False  False   True  True
# 1    ...  False   True   True   True  True
# 2    ...  False  False  False   True  True
# 3    ...   True  False  False  False  True
# 4    ...  False  False  False   True  True
# ..   ...    ...    ...    ...    ...   ...           ...        ...
# 142  ...  False  False  False   True  True
# 143  ...   True  False  False   True  True
# 144  ...  False  False  False  False  True
# 145  ...  False  False  False   True  True
# 146  ...  False  False  False   True  True
#
#      District_6 District_7 Other_neighborhoods
# 0
# 1
# 2
# 3
# 4
# ..          ...        ...                 ...
# 142
# 143
# 144
# 145
# 146
#
# [870 rows x 117 columns]

# %% [markdown]
# Change column values of DataFrame District_1245_new

# %%
District_1245_new['District_1245']=1
District_1245_new['District_3']=0
District_1245_new['District_6']=0
District_1245_new['District_7']=0
District_1245_new['Other_neighborhoods']=0
#Check
District_1245_new
# Out:
#      Index       id                           listing_url     scrape_id  \
# 0     2158  3279728  https://www.airbnb.com/rooms/3279728  2.016010e+13
# 1     2159  8446766  https://www.airbnb.com/rooms/8446766  2.016010e+13
# 2     2160  9733841  https://www.airbnb.com/rooms/9733841  2.016010e+13
# 3     2161  5852034  https://www.airbnb.com/rooms/5852034  2.016010e+13
# 4     2162  1851837  https://www.airbnb.com/rooms/1851837  2.016010e+13
# ..     ...      ...                                   ...           ...
# 142   3269  6438099  https://www.airbnb.com/rooms/6438099  2.016010e+13
# 143   3270  7650458  https://www.airbnb.com/rooms/7650458  2.016010e+13
# 144   3271  7219541  https://www.airbnb.com/rooms/7219541  2.016010e+13
# 145   3272  4092037  https://www.airbnb.com/rooms/4092037  2.016010e+13
# 146   3273   475361   https://www.airbnb.com/rooms/475361  2.016010e+13
#
#     last_scraped                                 name  \
# 0       4/1/2016           Stylish West Seattle 3BD
# 1       4/1/2016       Beautiful West Seattle Getaway
# 2       4/1/2016  Private, Cozy, Convenient W Seattle
# 3       4/1/2016         Maiden Mansion - Tiny House
# 4       4/1/2016   Awesome cozy One Bedroom Apartment
# ..           ...                                  ...
# 142     4/1/2016       Private room with private bath
# 143     4/1/2016   Large, Beautiful, Affordable Condo
# 144     4/1/2016   A beautiful house with a lake view
# 145     4/1/2016          Modern 3 BR home in Seattle
# 146     4/1/2016  NE Seattle Artist Treehouse Suite!
#
#                                                summary  \
# 0    Recently remodeled mid century home is squarel...
# 1    Clean comfortable room, queen size memory foam...
# 2    Private bed and bath! Room features wonderful ...
# 3    I designed and built this tiny house to be a c...
# 4    Enjoy the-lower level of our home a great livi...
# ..                                                 ...
# 142  Private room with private bath and patio deck ...
# 143  Condo is beautifully appointed & comfortable. ...
# 144  Neighborhood, Seattle, near NE 123rd St and Sa...
# 145  Enjoy a brand-new modern home in Seattle just ...
# 146  Friendly, joyful, light: large space, part art...
#
#                                                  space  \
# 0    This is a clean, comfortable, safe and secure,...
# 1    You can bring your pets, under 10 minutes to d...
# 2    This space was designed to give you maximum co...
# 3    I designed and built this tiny house on wheels...
# 4    Enjoy the-lower level of our home a great livi...
# ..                                                 ...
# 142  Please excuse the mess in the picture. The act...
# 143   This is a top floor condo in a 16 unit building.
# 144                                                NaN
# 145  Enjoy a brand-new, modern home (occupied since...
# 146  Please note: Smokers need not apply!  :-D 1.  ...
#
#                                            description experiences_offered  \
# 0    Recently remodeled mid century home is squarel...                none
# 1    Clean comfortable room, queen size memory foam...                none
# 2    Private bed and bath! Room features wonderful ...                none
# 3    I designed and built this tiny house to be a c...                none
# 4    Enjoy the-lower level of our home a great livi...                none
# ..                                                 ...                 ...
# 142  Private room with private bath and patio deck ...                none
# 143  Condo is beautifully appointed & comfortable. ...                none
# 144  Neighborhood, Seattle, near NE 123rd St and Sa...                none
# 145  Enjoy a brand-new modern home in Seattle just ...                none
# 146  Friendly, joyful, light: large space, part art...                none
#
#      ...   _107   _108   _109     TV  _111 District_1245 District_3  \
# 0    ...  False  False  False   True  True             1          0
# 1    ...  False   True   True   True  True             1          0
# 2    ...  False  False  False   True  True             1          0
# 3    ...   True  False  False  False  True             1          0
# 4    ...  False  False  False   True  True             1          0
# ..   ...    ...    ...    ...    ...   ...           ...        ...
# 142  ...  False  False  False   True  True             1          0
# 143  ...   True  False  False   True  True             1          0
# 144  ...  False  False  False  False  True             1          0
# 145  ...  False  False  False   True  True             1          0
# 146  ...  False  False  False   True  True             1          0
#
#      District_6 District_7 Other_neighborhoods
# 0             0          0                   0
# 1             0          0                   0
# 2             0          0                   0
# 3             0          0                   0
# 4             0          0                   0
# ..          ...        ...                 ...
# 142           0          0                   0
# 143           0          0                   0
# 144           0          0                   0
# 145           0          0                   0
# 146           0          0                   0
#
# [870 rows x 117 columns]

# %% [markdown]
# Change column values of DataFrame District_3_new

# %%
District_3_new['District_1245']=0
District_3_new['District_3']=1
District_3_new['District_6']=0
District_3_new['District_7']=0
District_3_new['Other_neighborhoods']=0
#Check
District_3_new
# Out:
#      Index       id                           listing_url     scrape_id  \
# 0     2514  6214517  https://www.airbnb.com/rooms/6214517  2.016010e+13
# 1     2515  8036620  https://www.airbnb.com/rooms/8036620  2.016010e+13
# 2     2516  8152764  https://www.airbnb.com/rooms/8152764  2.016010e+13
# 3     2517  6837751  https://www.airbnb.com/rooms/6837751  2.016010e+13
# 4     2518  2459519  https://www.airbnb.com/rooms/2459519  2.016010e+13
# ..     ...      ...                                   ...           ...
# 931   1058  7048843  https://www.airbnb.com/rooms/7048843  2.016010e+13
# 932   1059   879181   https://www.airbnb.com/rooms/879181  2.016010e+13
# 933   1060  6423488  https://www.airbnb.com/rooms/6423488  2.016010e+13
# 934   1061  7241905  https://www.airbnb.com/rooms/7241905  2.016010e+13
# 935   1062  1246809  https://www.airbnb.com/rooms/1246809  2.016010e+13
#
#     last_scraped                                 name  \
# 0       4/1/2016  Chic 1 Bed with Fantastic Lake View
# 1       4/1/2016      Elegant home in N. Capitol Hill
# 2       4/1/2016       Beautiful Water View Apartment
# 3       4/1/2016      1908 Craftsman home - cozy room
# 4       4/1/2016  Fabulous Views of Lakes & Mountains
# ..           ...                                  ...
# 931     4/1/2016       Large Room, 2-mile to downtown
# 932     4/1/2016     In Jimi Hendrix's neighborhood 3
# 933     4/1/2016      Modern and cozy home in Seattle
# 934     4/1/2016  1 Bedroom Apt near Downtown Seattle
# 935     4/1/2016  1BdRm 3bds w/AC fits 6snug Near DT
#
#                                                summary  \
# 0    Sparkling new unit.  800 sq ft w/open Living/D...
# 1    A 4500 square foot elegant home that is the pe...
# 2    Our home is cozy with lots of natural light. T...
# 3    This listing is for a cozy room nestled in the...
# 4    Centrally located, minutes to downtown. Views ...
# ..                                                 ...
# 931  House is 2 miles from city center.  Private la...
# 932                                                NaN
# 933  Modern and green built home just a few minutes...
# 934  Hi! Our apartment comfortably accommodates 2 p...
# 935  This is a sweet 1 bed room mother in law suite...
#
#                                                  space  \
# 0    The apartment is a very private space, located...
# 1    Enter the front door, into a grand formal entr...
# 2    The view of Portage Bay makes this space very ...
# 3    Our space is close to all the activities that ...
# 4    Welcome! Our house is ideally located for visi...
# ..                                                 ...
# 931  House is two-level.  Your room is private with...
# 932  One well-furnished private room is available i...
# 933                                                NaN
# 934                                                NaN
# 935  Cozy one bed room unit  ***We require ALL gues...
#
#                                            description experiences_offered  \
# 0    Sparkling new unit.  800 sq ft w/open Living/D...                none
# 1    A 4500 square foot elegant home that is the pe...                none
# 2    Our home is cozy with lots of natural light. T...                none
# 3    This listing is for a cozy room nestled in the...                none
# 4    Centrally located, minutes to downtown. Views ...                none
# ..                                                 ...                 ...
# 931  House is 2 miles from city center.  Private la...                none
# 932  One well-furnished private room is available i...                none
# 933  Modern and green built home just a few minutes...                none
# 934  Hi! Our apartment comfortably accommodates 2 p...                none
# 935  This is a sweet 1 bed room mother in law suite...                none
#
#      ...   _107   _108   _109     TV  _111 District_1245 District_3  \
# 0    ...   True  False  False   True  True             0          1
# 1    ...  False  False  False   True  True             0          1
# 2    ...  False  False  False  False  True             0          1
# 3    ...  False  False  False   True  True             0          1
# 4    ...   True  False  False   True  True             0          1
# ..   ...    ...    ...    ...    ...   ...           ...        ...
# 931  ...  False  False  False  False  True             0          1
# 932  ...  False  False  False  False  True             0          1
# 933  ...  False  False  False   True  True             0          1
# 934  ...  False  False  False   True  True             0          1
# 935  ...   True  False  False   True  True             0          1
#
#      District_6 District_7 Other_neighborhoods
# 0             0          0                   0
# 1             0          0                   0
# 2             0          0                   0
# 3             0          0                   0
# 4             0          0                   0
# ..          ...        ...                 ...
# 931           0          0                   0
# 932           0          0                   0
# 933           0          0                   0
# 934           0          0                   0
# 935           0          0                   0
#
# [936 rows x 117 columns]

# %% [markdown]
# Change column values of DataFrame District_6_new

# %%
District_6_new['District_1245']=0
District_6_new['District_3']=0
District_6_new['District_6']=1
District_6_new['District_7']=0
District_6_new['Other_neighborhoods']=0
#Check
District_6_new
# Out:
#      Index        id                            listing_url     scrape_id  \
# 0       65   7077910   https://www.airbnb.com/rooms/7077910  2.016010e+13
# 1       66   3772674   https://www.airbnb.com/rooms/3772674  2.016010e+13
# 2       67   7021906   https://www.airbnb.com/rooms/7021906  2.016010e+13
# 3       68   7618605   https://www.airbnb.com/rooms/7618605  2.016010e+13
# 4       69  10234558  https://www.airbnb.com/rooms/10234558  2.016010e+13
# ..     ...       ...                                    ...           ...
# 225   3300   1488166   https://www.airbnb.com/rooms/1488166  2.016010e+13
# 226   3301    463768    https://www.airbnb.com/rooms/463768  2.016010e+13
# 227   3302   4334804   https://www.airbnb.com/rooms/4334804  2.016010e+13
# 228   3303   9331145   https://www.airbnb.com/rooms/9331145  2.016010e+13
# 229   3304   7389248   https://www.airbnb.com/rooms/7389248  2.016010e+13
#
#     last_scraped                                 name  \
# 0       4/1/2016  Modern Townhouse, Heart of Ballard!
# 1       4/1/2016               Cozy Ballard Apartment
# 2       4/1/2016     Plum Modern - 5 bdrm Tranquility
# 3       4/1/2016  1BR-Ultra Hip Ballard-Walk to Bars!
# 4       4/1/2016   Cozy BR in heart of lively Ballard
# ..           ...                                  ...
# 225     4/1/2016  Entire Home - Beautiful Sunset Hill
# 226     4/1/2016      delux comfort+ in coolest 'hood
# 227     4/1/2016    New, modern, kid-friendly home...
# 228     4/1/2016                 B&B on the Salty Sea
# 229     4/1/2016             Luxury Ballard Town Home
#
#                                                summary  \
# 0    LEED certified "green" 3-story townhouse with ...
# 1    You'll feel right at home in our private entra...
# 2    A beautiful sun-filled homes in an amazing Bal...
# 3    This 1BR is in a great location!  Walking dist...
# 4    Quite and comfy room for two with private bath...
# ..                                                 ...
# 225  Immaculate, light-filled home in Sunset Hill w...
# 226  Relish in four-star comfort in a contemporary ...
# 227  Brand new, spacious 2-brdm*, 2.5 bath home jus...
# 228        A 1977 Islander Freeport with a happy crew!
# 229  Luxury Ballard home with beautiful rooftop vie...
#
#                                                  space  \
# 0    3 story townhouse, modern design, beautiful hi...
# 1    Looking for a place that feels like home?  Our...
# 2    Welcome to the Plum house, a modern home finis...
# 3    1BR, open kitchen, large patio, large bathroom...
# 4    This is a condo building with secure access an...
# ..                                                 ...
# 225  _______________________ BEDROOMS AND BATHS: 3 ...
# 226  Relax and enjoy all the amenities of our 3,400...
# 227  Our home has all the creature comforts of a Cr...
# 228                                                NaN
# 229  Our home is equipped with CitiQuiet soundproof...
#
#                                            description experiences_offered  \
# 0    LEED certified "green" 3-story townhouse with ...                none
# 1    You'll feel right at home in our private entra...                none
# 2    A beautiful sun-filled homes in an amazing Bal...                none
# 3    This 1BR is in a great location!  Walking dist...                none
# 4    Quite and comfy room for two with private bath...                none
# ..                                                 ...                 ...
# 225  Immaculate, light-filled home in Sunset Hill w...                none
# 226  Relish in four-star comfort in a contemporary ...                none
# 227  Brand new, spacious 2-brdm*, 2.5 bath home jus...                none
# 228        A 1977 Islander Freeport with a happy crew!                none
# 229  Luxury Ballard home with beautiful rooftop vie...                none
#
#      ...   _107   _108   _109    TV   _111 District_1245 District_3  \
# 0    ...  False  False   True  True   True             0          0
# 1    ...  False  False  False  True   True             0          0
# 2    ...  False  False  False  True   True             0          0
# 3    ...  False  False  False  True   True             0          0
# 4    ...  False  False  False  True   True             0          0
# ..   ...    ...    ...    ...   ...    ...           ...        ...
# 225  ...   True  False  False  True   True             0          0
# 226  ...  False  False  False  True   True             0          0
# 227  ...  False  False  False  True   True             0          0
# 228  ...  False  False  False  True  False             0          0
# 229  ...  False  False  False  True   True             0          0
#
#      District_6 District_7 Other_neighborhoods
# 0             1          0                   0
# 1             1          0                   0
# 2             1          0                   0
# 3             1          0                   0
# 4             1          0                   0
# ..          ...        ...                 ...
# 225           1          0                   0
# 226           1          0                   0
# 227           1          0                   0
# 228           1          0                   0
# 229           1          0                   0
#
# [230 rows x 117 columns]

# %% [markdown]
# Change column values of DataFrame District_7_new

# %%
District_7_new['District_1245']=0
District_7_new['District_3']=0
District_7_new['District_6']=0
District_7_new['District_7']=1
District_7_new['Other_neighborhoods']=0
#Check
District_7_new
# Out:
#      Index        id                            listing_url     scrape_id  \
# 0     1063  10273158  https://www.airbnb.com/rooms/10273158  2.016010e+13
# 1     1064   5615620   https://www.airbnb.com/rooms/5615620  2.016010e+13
# 2     1065    936484    https://www.airbnb.com/rooms/936484  2.016010e+13
# 3     1066   5415077   https://www.airbnb.com/rooms/5415077  2.016010e+13
# 4     1067    938785    https://www.airbnb.com/rooms/938785  2.016010e+13
# ..     ...       ...                                    ...           ...
# 981   1917   2134911   https://www.airbnb.com/rooms/2134911  2.016010e+13
# 982   1918   5002964   https://www.airbnb.com/rooms/5002964  2.016010e+13
# 983   1919   6780615   https://www.airbnb.com/rooms/6780615  2.016010e+13
# 984   1920   2586642   https://www.airbnb.com/rooms/2586642  2.016010e+13
# 985   1921   9490093   https://www.airbnb.com/rooms/9490093  2.016010e+13
#
#     last_scraped                                 name  \
# 0       4/1/2016   Pike Place High Rise 99 Walk Score
# 1       4/1/2016    Downtown Apt by Pike Place Market
# 2       4/1/2016   Marketside Flats next to Pike! MS1
# 3       4/1/2016  Spacious Room in Pike Place Market!
# 4       4/1/2016  Best Ocean Views By Pike Place! PA1
# ..           ...                                  ...
# 981     4/1/2016  The Studio at Mibbett Hollow - Boat
# 982     4/1/2016     10 Minutes from Downtown Seattle
# 983     4/1/2016             Modern Oasis in Magnolia
# 984     4/1/2016       Charming modern 2 bdm getaway
# 985     4/1/2016  Chic One Bedroom Condo in Magnolia!
#
#                                                summary  \
# 0    Out your front door is the heart and soul of S...
# 1    This cozy apartment is stocked with all the am...
# 2    The Marketside Flats is a fantastic home base ...
# 3    My spacious & private downtown Seattle condo i...
# 4    Post Alley Court offers amazing views of Ellio...
# ..                                                 ...
# 981  A quiet space with separate Entrance. The bath...
# 982  Easy access from the SEA-TAC.   10 minutes fro...
# 983  This mid-century modern apartment building has...
# 984  New modern mother in law unit built 2014 in a ...
# 985  This cozy, chic, and modern condo sits in the ...
#
#                                                  space  \
# 0    This beautiful new high rise studio is in the ...
# 1    This studio apartment features living room spa...
# 2    LOCATED RIGHT NEXT TO PIKE PLACE MARKET!!! You...
# 3    This large 2 bed 2 bath condo with floor-to-ce...
# 4    Water views from balcony, only 1/2 block to Pi...
# ..                                                 ...
# 981  The “Studio at Mibbett Hollow' is in a Beautif...
# 982  Upper floor balcony where you can enjoy squirr...
# 983  Bright and modern luxury apartment ideally loc...
# 984  Serene and modern 2 bedroom/1 bath guest house...
# 985  Beautifully decorated like a boutique hotel. T...
#
#                                            description experiences_offered  \
# 0    Out your front door is the heart and soul of S...                none
# 1    This cozy apartment is stocked with all the am...                none
# 2    The Marketside Flats is a fantastic home base ...                none
# 3    My spacious & private downtown Seattle condo i...                none
# 4    Post Alley Court offers amazing views of Ellio...                none
# ..                                                 ...                 ...
# 981  A quiet space with separate Entrance. The bath...                none
# 982  Easy access from the SEA-TAC.   10 minutes fro...                none
# 983  This mid-century modern apartment building has...                none
# 984  New modern mother in law unit built 2014 in a ...                none
# 985  This cozy, chic, and modern condo sits in the ...                none
#
#      ...   _107   _108   _109    TV  _111 District_1245 District_3  \
# 0    ...   True  False  False  True  True             0          0
# 1    ...  False  False  False  True  True             0          0
# 2    ...  False  False  False  True  True             0          0
# 3    ...   True   True  False  True  True             0          0
# 4    ...  False  False  False  True  True             0          0
# ..   ...    ...    ...    ...   ...   ...           ...        ...
# 981  ...  False  False  False  True  True             0          0
# 982  ...   True  False  False  True  True             0          0
# 983  ...   True  False  False  True  True             0          0
# 984  ...  False  False  False  True  True             0          0
# 985  ...   True  False  False  True  True             0          0
#
#      District_6 District_7 Other_neighborhoods
# 0             0          1                   0
# 1             0          1                   0
# 2             0          1                   0
# 3             0          1                   0
# 4             0          1                   0
# ..          ...        ...                 ...
# 981           0          1                   0
# 982           0          1                   0
# 983           0          1                   0
# 984           0          1                   0
# 985           0          1                   0
#
# [986 rows x 117 columns]

# %% [markdown]
# Change column values of DataFrame Other_neighborhoods

# %%
Other_neighborhoods_new['District_1245']=0
Other_neighborhoods_new['District_3']=0
Other_neighborhoods_new['District_6']=0
Other_neighborhoods_new['District_7']=0
Other_neighborhoods_new['Other_neighborhoods']=1
#Check
Other_neighborhoods_new
# Out:
#      Index       id                           listing_url     scrape_id  \
# 0      280   314180   https://www.airbnb.com/rooms/314180  2.016010e+13
# 1      281  8670079  https://www.airbnb.com/rooms/8670079  2.016010e+13
# 2      282  4868135  https://www.airbnb.com/rooms/4868135  2.016010e+13
# 3      283  5336585  https://www.airbnb.com/rooms/5336585  2.016010e+13
# 4      284  1427103  https://www.airbnb.com/rooms/1427103  2.016010e+13
# ..     ...      ...                                   ...           ...
# 789   3809  6120046  https://www.airbnb.com/rooms/6120046  2.016010e+13
# 790   3810   262764   https://www.airbnb.com/rooms/262764  2.016010e+13
# 791   3811  8578490  https://www.airbnb.com/rooms/8578490  2.016010e+13
# 792   3812  3383329  https://www.airbnb.com/rooms/3383329  2.016010e+13
# 793   3813  8101950  https://www.airbnb.com/rooms/8101950  2.016010e+13
#
#     last_scraped                                 name  \
# 0       4/1/2016   Sunny Home w/ Views in Wallingford
# 1       4/1/2016       Furnished, great spot, near UW
# 2       4/1/2016  Designer 2 Bdrm Fremont/Wallingford
# 3       4/1/2016         Beautiful Loft Apartment UW
# 4       4/1/2016    Wallingford Private 1BD Apartment
# ..           ...                                  ...
# 789     4/1/2016        Lake Veiw Cottage  in Fremont
# 790     4/1/2016                    Fremont Farmhouse
# 791     4/1/2016       Super Convenient Top Floor Apt
# 792     4/1/2016  OF THE TREE & CLOUDS. KID FRIENDLY!
# 793     4/1/2016   3BR Mountain View House in Seattle
#
#                                                summary  \
# 0    My historic and recently remodeled house is on...
# 1    This furnished home is a sweet bungalow in a g...
# 2    Luxurious, new,spacious 2 bdrm apartment in on...
# 3    I have a great loft apartment in the Wallingfo...
# 4    Our eco-friendly furnished apartment features ...
# ..                                                 ...
# 789  From the deck of this quaint little apartment ...
# 790  Our 2BR/1 bath home in Fremont's most fun neig...
# 791  In the true spirit of AirBNB this unit is avai...
# 792  Of the Tree & Clouds' "Roots" apartment is 8 b...
# 793  Our 3BR/2BA house boasts incredible views of t...
#
#                                                  space  \
# 0    Enjoy commanding views of downtown, Mt. Rainer...
# 1    Great for families, or visiting guests needing...
# 2    Luxurious and all new spacious 2 bedroom apart...
# 3                                                  NaN
# 4    Our basement apartment is painted with low VOC...
# ..                                                 ...
# 789  This one bedroom apartment (Hippy Shack) is de...
# 790  1200 ft2 2BR, 1 Bath farmhouse with a large, t...
# 791  The building is older (1970's) so not the mode...
# 792  The 1-bedroom, ground-floor Roots apartment is...
# 793  Our 3BR/2BA house bright, stylish, and wheelch...
#
#                                            description experiences_offered  \
# 0    My historic and recently remodeled house is on...                none
# 1    This furnished home is a sweet bungalow in a g...                none
# 2    Luxurious, new,spacious 2 bdrm apartment in on...                none
# 3    I have a great loft apartment in the Wallingfo...                none
# 4    Our eco-friendly furnished apartment features ...                none
# ..                                                 ...                 ...
# 789  From the deck of this quaint little apartment ...                none
# 790  Our 2BR/1 bath home in Fremont's most fun neig...                none
# 791  In the true spirit of AirBNB this unit is avai...                none
# 792  Of the Tree & Clouds' "Roots" apartment is 8 b...                none
# 793  Our 3BR/2BA house boasts incredible views of t...                none
#
#      ...   _107   _108   _109     TV   _111 District_1245 District_3  \
# 0    ...  False  False  False   True   True             0          0
# 1    ...   True  False  False   True   True             0          0
# 2    ...  False  False  False   True   True             0          0
# 3    ...  False   True  False  False  False             0          0
# 4    ...  False  False  False  False   True             0          0
# ..   ...    ...    ...    ...    ...    ...           ...        ...
# 789  ...  False  False  False  False   True             0          0
# 790  ...   True  False  False   True   True             0          0
# 791  ...   True  False  False   True   True             0          0
# 792  ...  False  False  False  False   True             0          0
# 793  ...  False  False  False   True   True             0          0
#
#      District_6 District_7 Other_neighborhoods
# 0             0          0                   1
# 1             0          0                   1
# 2             0          0                   1
# 3             0          0                   1
# 4             0          0                   1
# ..          ...        ...                 ...
# 789           0          0                   1
# 790           0          0                   1
# 791           0          0                   1
# 792           0          0                   1
# 793           0          0                   1
#
# [794 rows x 117 columns]

# %% [markdown]
# concatenate the 5 dataframes together and name the new dataframe concatenate

# %%
new_listing=pd.concat([District_1245_new,District_3_new,District_6_new,District_7_new,Other_neighborhoods_new])
#check
new_listing
# Out:
#      Index       id                           listing_url     scrape_id  \
# 0     2158  3279728  https://www.airbnb.com/rooms/3279728  2.016010e+13
# 1     2159  8446766  https://www.airbnb.com/rooms/8446766  2.016010e+13
# 2     2160  9733841  https://www.airbnb.com/rooms/9733841  2.016010e+13
# 3     2161  5852034  https://www.airbnb.com/rooms/5852034  2.016010e+13
# 4     2162  1851837  https://www.airbnb.com/rooms/1851837  2.016010e+13
# ..     ...      ...                                   ...           ...
# 789   3809  6120046  https://www.airbnb.com/rooms/6120046  2.016010e+13
# 790   3810   262764   https://www.airbnb.com/rooms/262764  2.016010e+13
# 791   3811  8578490  https://www.airbnb.com/rooms/8578490  2.016010e+13
# 792   3812  3383329  https://www.airbnb.com/rooms/3383329  2.016010e+13
# 793   3813  8101950  https://www.airbnb.com/rooms/8101950  2.016010e+13
#
#     last_scraped                                 name  \
# 0       4/1/2016           Stylish West Seattle 3BD
# 1       4/1/2016       Beautiful West Seattle Getaway
# 2       4/1/2016  Private, Cozy, Convenient W Seattle
# 3       4/1/2016         Maiden Mansion - Tiny House
# 4       4/1/2016   Awesome cozy One Bedroom Apartment
# ..           ...                                  ...
# 789     4/1/2016        Lake Veiw Cottage  in Fremont
# 790     4/1/2016                    Fremont Farmhouse
# 791     4/1/2016       Super Convenient Top Floor Apt
# 792     4/1/2016  OF THE TREE & CLOUDS. KID FRIENDLY!
# 793     4/1/2016   3BR Mountain View House in Seattle
#
#                                                summary  \
# 0    Recently remodeled mid century home is squarel...
# 1    Clean comfortable room, queen size memory foam...
# 2    Private bed and bath! Room features wonderful ...
# 3    I designed and built this tiny house to be a c...
# 4    Enjoy the-lower level of our home a great livi...
# ..                                                 ...
# 789  From the deck of this quaint little apartment ...
# 790  Our 2BR/1 bath home in Fremont's most fun neig...
# 791  In the true spirit of AirBNB this unit is avai...
# 792  Of the Tree & Clouds' "Roots" apartment is 8 b...
# 793  Our 3BR/2BA house boasts incredible views of t...
#
#                                                  space  \
# 0    This is a clean, comfortable, safe and secure,...
# 1    You can bring your pets, under 10 minutes to d...
# 2    This space was designed to give you maximum co...
# 3    I designed and built this tiny house on wheels...
# 4    Enjoy the-lower level of our home a great livi...
# ..                                                 ...
# 789  This one bedroom apartment (Hippy Shack) is de...
# 790  1200 ft2 2BR, 1 Bath farmhouse with a large, t...
# 791  The building is older (1970's) so not the mode...
# 792  The 1-bedroom, ground-floor Roots apartment is...
# 793  Our 3BR/2BA house bright, stylish, and wheelch...
#
#                                            description experiences_offered  \
# 0    Recently remodeled mid century home is squarel...                none
# 1    Clean comfortable room, queen size memory foam...                none
# 2    Private bed and bath! Room features wonderful ...                none
# 3    I designed and built this tiny house to be a c...                none
# 4    Enjoy the-lower level of our home a great livi...                none
# ..                                                 ...                 ...
# 789  From the deck of this quaint little apartment ...                none
# 790  Our 2BR/1 bath home in Fremont's most fun neig...                none
# 791  In the true spirit of AirBNB this unit is avai...                none
# 792  Of the Tree & Clouds' "Roots" apartment is 8 b...                none
# 793  Our 3BR/2BA house boasts incredible views of t...                none
#
#      ...   _107   _108   _109     TV  _111 District_1245 District_3  \
# 0    ...  False  False  False   True  True             1          0
# 1    ...  False   True   True   True  True             1          0
# 2    ...  False  False  False   True  True             1          0
# 3    ...   True  False  False  False  True             1          0
# 4    ...  False  False  False   True  True             1          0
# ..   ...    ...    ...    ...    ...   ...           ...        ...
# 789  ...  False  False  False  False  True             0          0
# 790  ...   True  False  False   True  True             0          0
# 791  ...   True  False  False   True  True             0          0
# 792  ...  False  False  False  False  True             0          0
# 793  ...  False  False  False   True  True             0          0
#
#      District_6 District_7 Other_neighborhoods
# 0             0          0                   0
# 1             0          0                   0
# 2             0          0                   0
# 3             0          0                   0
# 4             0          0                   0
# ..          ...        ...                 ...
# 789           0          0                   1
# 790           0          0                   1
# 791           0          0                   1
# 792           0          0                   1
# 793           0          0                   1
#
# [3816 rows x 117 columns]

# %% [markdown]
# Convert data type from int to object

# %%
new_listing['District_1245'] = new_listing['District_1245'].astype(object)
new_listing['District_3'] = new_listing['District_3'].astype(object)
new_listing['District_6'] = new_listing['District_6'].astype(object)
new_listing['District_7'] = new_listing['District_7'].astype(object)
new_listing['Other_neighborhoods'] = new_listing['Other_neighborhoods'].astype(object)

# %%
new_listing
# Out:
#      Index       id                           listing_url     scrape_id  \
# 0     2158  3279728  https://www.airbnb.com/rooms/3279728  2.016010e+13
# 1     2159  8446766  https://www.airbnb.com/rooms/8446766  2.016010e+13
# 2     2160  9733841  https://www.airbnb.com/rooms/9733841  2.016010e+13
# 3     2161  5852034  https://www.airbnb.com/rooms/5852034  2.016010e+13
# 4     2162  1851837  https://www.airbnb.com/rooms/1851837  2.016010e+13
# ..     ...      ...                                   ...           ...
# 789   3809  6120046  https://www.airbnb.com/rooms/6120046  2.016010e+13
# 790   3810   262764   https://www.airbnb.com/rooms/262764  2.016010e+13
# 791   3811  8578490  https://www.airbnb.com/rooms/8578490  2.016010e+13
# 792   3812  3383329  https://www.airbnb.com/rooms/3383329  2.016010e+13
# 793   3813  8101950  https://www.airbnb.com/rooms/8101950  2.016010e+13
#
#     last_scraped                                 name  \
# 0       4/1/2016           Stylish West Seattle 3BD
# 1       4/1/2016       Beautiful West Seattle Getaway
# 2       4/1/2016  Private, Cozy, Convenient W Seattle
# 3       4/1/2016         Maiden Mansion - Tiny House
# 4       4/1/2016   Awesome cozy One Bedroom Apartment
# ..           ...                                  ...
# 789     4/1/2016        Lake Veiw Cottage  in Fremont
# 790     4/1/2016                    Fremont Farmhouse
# 791     4/1/2016       Super Convenient Top Floor Apt
# 792     4/1/2016  OF THE TREE & CLOUDS. KID FRIENDLY!
# 793     4/1/2016   3BR Mountain View House in Seattle
#
#                                                summary  \
# 0    Recently remodeled mid century home is squarel...
# 1    Clean comfortable room, queen size memory foam...
# 2    Private bed and bath! Room features wonderful ...
# 3    I designed and built this tiny house to be a c...
# 4    Enjoy the-lower level of our home a great livi...
# ..                                                 ...
# 789  From the deck of this quaint little apartment ...
# 790  Our 2BR/1 bath home in Fremont's most fun neig...
# 791  In the true spirit of AirBNB this unit is avai...
# 792  Of the Tree & Clouds' "Roots" apartment is 8 b...
# 793  Our 3BR/2BA house boasts incredible views of t...
#
#                                                  space  \
# 0    This is a clean, comfortable, safe and secure,...
# 1    You can bring your pets, under 10 minutes to d...
# 2    This space was designed to give you maximum co...
# 3    I designed and built this tiny house on wheels...
# 4    Enjoy the-lower level of our home a great livi...
# ..                                                 ...
# 789  This one bedroom apartment (Hippy Shack) is de...
# 790  1200 ft2 2BR, 1 Bath farmhouse with a large, t...
# 791  The building is older (1970's) so not the mode...
# 792  The 1-bedroom, ground-floor Roots apartment is...
# 793  Our 3BR/2BA house bright, stylish, and wheelch...
#
#                                            description experiences_offered  \
# 0    Recently remodeled mid century home is squarel...                none
# 1    Clean comfortable room, queen size memory foam...                none
# 2    Private bed and bath! Room features wonderful ...                none
# 3    I designed and built this tiny house to be a c...                none
# 4    Enjoy the-lower level of our home a great livi...                none
# ..                                                 ...                 ...
# 789  From the deck of this quaint little apartment ...                none
# 790  Our 2BR/1 bath home in Fremont's most fun neig...                none
# 791  In the true spirit of AirBNB this unit is avai...                none
# 792  Of the Tree & Clouds' "Roots" apartment is 8 b...                none
# 793  Our 3BR/2BA house boasts incredible views of t...                none
#
#      ...   _107   _108   _109     TV  _111 District_1245 District_3  \
# 0    ...  False  False  False   True  True             1          0
# 1    ...  False   True   True   True  True             1          0
# 2    ...  False  False  False   True  True             1          0
# 3    ...   True  False  False  False  True             1          0
# 4    ...  False  False  False   True  True             1          0
# ..   ...    ...    ...    ...    ...   ...           ...        ...
# 789  ...  False  False  False  False  True             0          0
# 790  ...   True  False  False   True  True             0          0
# 791  ...   True  False  False   True  True             0          0
# 792  ...  False  False  False  False  True             0          0
# 793  ...  False  False  False   True  True             0          0
#
#      District_6 District_7 Other_neighborhoods
# 0             0          0                   0
# 1             0          0                   0
# 2             0          0                   0
# 3             0          0                   0
# 4             0          0                   0
# ..          ...        ...                 ...
# 789           0          0                   1
# 790           0          0                   1
# 791           0          0                   1
# 792           0          0                   1
# 793           0          0                   1
#
# [3816 rows x 117 columns]

# %%
new_listing.to_csv('..\\dataset_filter\\new_listing.csv',index=False)
