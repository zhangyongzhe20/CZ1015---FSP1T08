# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
listings_2 = pd.read_csv('seattle/listings_2.csv')

# %%
listings_2.describe()
# Out:
#                  id       host_id  host_listings_count  \
# count  3.818000e+03  3.818000e+03          3818.000000
# mean   5.550111e+06  1.578556e+07             7.157412
# std    2.962660e+06  1.458382e+07            28.620929
# min    3.335000e+03  4.193000e+03             1.000000
# 25%    3.258256e+06  3.275204e+06             1.000000
# 50%    6.118244e+06  1.055814e+07             1.000000
# 75%    8.035127e+06  2.590309e+07             3.000000
# max    1.034016e+07  5.320861e+07           502.000000
#
#        host_total_listings_count  accommodates    bathrooms     bedrooms  \
# count                3818.000000   3818.000000  3818.000000  3818.000000
# mean                    7.157412      3.349398     1.258643     1.308015
# std                    28.620929      1.977599     0.589365     0.883252
# min                     1.000000      1.000000     0.000000     0.000000
# 25%                     1.000000      2.000000     1.000000     1.000000
# ...

# %%
listings_2.describe(include=["O"])
# Out:
#                           name  \
# count                     3818
# unique                    3792
# top     Capitol Hill Apartment
# freq                         3
#
#                                                   summary  \
# count                                                3818
# unique                                               3477
# top     This is a modern fully-furnished studio apartm...
# freq                                                   18
#
#                                                     space  \
# count                                                3818
# unique                                               3119
# top     *Note: This fall, there will be major renovati...
# freq                                                   15
#
#                                               description  \
# count                                                3818
# unique                                               3742
# ...
